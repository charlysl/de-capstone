# %%
import findspark
findspark.init()

import pyspark.sql.functions as F

import pandas as pd
pd.set_option('display.max_rows', 1000)

from etl import SparkETL

# %%
etl = SparkETL()

# %%
i94_data_dictionary = etl.read_clean_table('i94_data_dictionary')

# %%
i94_data_dictionary.printSchema()
# Out:
# root
#  |-- I94ADDR: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- I94CIT: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- I94MODE: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- I94PORT: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- VISATYPE: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)

# %%
def explode_countries(df):
    return (
        df
        .select(
            F.explode('I94CIT')
        )
        .select(
            F.element_at(F.col('col'), 1).alias('country_id'),
            F.element_at(F.col('col'), 2).alias('country')
        )
    )

# %%
def clean_mexico(df):
    return (
        df
        .withColumn(
            'country',
            F.expr("""
                IF(
                    country_id = 582,
                    'MEXICO',
                    country
                )
            """)
        )
    )

# %%
def clean_country(df):
    return (
        i94_data_dictionary
        .pipe(explode_countries)
        .pipe(clean_mexico)
    )

# %%
def save_clean_country():
    etl.save_clean_table(i94_data_dictionary.pipe(clean_country), 'country')

# %%
save_clean_country()

# %%
etl.read_clean_table('country').toPandas()
# Out:
#     country_id                                           country
# 0          582                                            MEXICO
# 1          236                                       AFGHANISTAN
# 2          101                                           ALBANIA
# 3          316                                           ALGERIA
# 4          102                                           ANDORRA
# 5          324                                            ANGOLA
# 6          529                                          ANGUILLA
# 7          518                                   ANTIGUA-BARBUDA
# 8          687                                        ARGENTINA
# 9          151                                           ARMENIA
# 10         532                                             ARUBA
# 11         438                                         AUSTRALIA
# 12         103                                           AUSTRIA
# 13         152                                        AZERBAIJAN
# 14         512                                           BAHAMAS
# 15         298                                           BAHRAIN
# 16         274                                        BANGLADESH
# 17         513                                          BARBADOS
# 18         104                                           BELGIUM
# 19         581                                            BELIZE
# 20         386                                             BENIN
# 21         509                                           BERMUDA
# 22         153                                           BELARUS
# 23         242                                            BHUTAN
# 24         688                                           BOLIVIA
# 25         717                       BONAIRE, ST EUSTATIUS, SABA
# 26         164                                BOSNIA-HERZEGOVINA
# 27         336                                          BOTSWANA
# 28         689                                            BRAZIL
# 29         525                            BRITISH VIRGIN ISLANDS
# 30         217                                            BRUNEI
# 31         105                                          BULGARIA
# 32         393                                      BURKINA FASO
# 33         243                                             BURMA
# 34         375                                           BURUNDI
# 35         310                                          CAMEROON
# 36         326                                        CAPE VERDE
# 37         526                                    CAYMAN ISLANDS
# 38         383                          CENTRAL AFRICAN REPUBLIC
# 39         384                                              CHAD
# 40         690                                             CHILE
# 41         245                                        CHINA, PRC
# 42         721                                           CURACAO
# 43         270                                  CHRISTMAS ISLAND
# 44         271                                     COCOS ISLANDS
# 45         691                                          COLOMBIA
# 46         317                                           COMOROS
# 47         385                                             CONGO
# 48         467                                      COOK ISLANDS
# 49         575                                        COSTA RICA
# 50         165                                           CROATIA
# 51         584                                              CUBA
# 52         218                                            CYPRUS
# 53         140                                    CZECH REPUBLIC
# 54         723                   FAROE ISLANDS (PART OF DENMARK)
# 55         108                                           DENMARK
# 56         322                                          DJIBOUTI
# 57         519                                          DOMINICA
# 58         585                                DOMINICAN REPUBLIC
# 59         240                                        EAST TIMOR
# 60         692                                           ECUADOR
# 61         368                                             EGYPT
# 62         576                                       EL SALVADOR
# 63         399                                 EQUATORIAL GUINEA
# 64         372                                           ERITREA
# 65         109                                           ESTONIA
# 66         369                                          ETHIOPIA
# 67         604                                  FALKLAND ISLANDS
# 68         413                                              FIJI
# 69         110                                           FINLAND
# 70         111                                            FRANCE
# 71         601                                     FRENCH GUIANA
# 72         411                                  FRENCH POLYNESIA
# 73         387                                             GABON
# 74         338                                            GAMBIA
# 75         758                                        GAZA STRIP
# 76         154                                           GEORGIA
# 77         112                                           GERMANY
# 78         339                                             GHANA
# 79         143                                         GIBRALTAR
# 80         113                                            GREECE
# 81         520                                           GRENADA
# 82         507                                        GUADELOUPE
# 83         577                                         GUATEMALA
# 84         382                                            GUINEA
# 85         327                                     GUINEA-BISSAU
# 86         603                                            GUYANA
# 87         586                                             HAITI
# 88         726                            HEARD AND MCDONALD IS.
# 89         149                                  HOLY SEE/VATICAN
# 90         528                                          HONDURAS
# 91         206                                         HONG KONG
# 92         114                                           HUNGARY
# 93         115                                           ICELAND
# 94         213                                             INDIA
# 95         759                       INDIAN OCEAN AREAS (FRENCH)
# 96         729                            INDIAN OCEAN TERRITORY
# 97         204                                         INDONESIA
# 98         249                                              IRAN
# 99         250                                              IRAQ
# 100        116                                           IRELAND
# 101        251                                            ISRAEL
# 102        117                                             ITALY
# 103        388                                       IVORY COAST
# 104        514                                           JAMAICA
# 105        209                                             JAPAN
# 106        253                                            JORDAN
# 107        201                                         KAMPUCHEA
# 108        155                                        KAZAKHSTAN
# 109        340                                             KENYA
# 110        414                                          KIRIBATI
# 111        732                                            KOSOVO
# 112        272                                            KUWAIT
# 113        156                                        KYRGYZSTAN
# 114        203                                              LAOS
# 115        118                                            LATVIA
# 116        255                                           LEBANON
# 117        335                                           LESOTHO
# 118        370                                           LIBERIA
# 119        381                                             LIBYA
# 120        119                                     LIECHTENSTEIN
# 121        120                                         LITHUANIA
# 122        121                                        LUXEMBOURG
# 123        214                                             MACAU
# 124        167                                         MACEDONIA
# 125        320                                        MADAGASCAR
# 126        345                                            MALAWI
# 127        273                                          MALAYSIA
# 128        220                                          MALDIVES
# 129        392                                              MALI
# 130        145                                             MALTA
# 131        472                                  MARSHALL ISLANDS
# 132        511                                        MARTINIQUE
# 133        389                                        MAURITANIA
# 134        342                                         MAURITIUS
# 135        760                         MAYOTTE (AFRICA - FRENCH)
# 136        473                        MICRONESIA, FED. STATES OF
# 137        157                                           MOLDOVA
# 138        122                                            MONACO
# 139        299                                          MONGOLIA
# 140        735                                        MONTENEGRO
# 141        521                                        MONTSERRAT
# 142        332                                           MOROCCO
# 143        329                                        MOZAMBIQUE
# 144        371                                           NAMIBIA
# 145        440                                             NAURU
# 146        257                                             NEPAL
# 147        123                                       NETHERLANDS
# 148        508                              NETHERLANDS ANTILLES
# 149        409                                     NEW CALEDONIA
# 150        464                                       NEW ZEALAND
# 151        579                                         NICARAGUA
# 152        390                                             NIGER
# 153        343                                           NIGERIA
# 154        470                                              NIUE
# 155        275                                       NORTH KOREA
# 156        124                                            NORWAY
# 157        256                                              OMAN
# 158        258                                          PAKISTAN
# 159        474                                             PALAU
# 160        743                                         PALESTINE
# 161        504                                            PANAMA
# 162        441                                  PAPUA NEW GUINEA
# 163        693                                          PARAGUAY
# 164        694                                              PERU
# 165        260                                       PHILIPPINES
# 166        416                                  PITCAIRN ISLANDS
# 167        107                                            POLAND
# 168        126                                          PORTUGAL
# 169        297                                             QATAR
# 170        748                           REPUBLIC OF SOUTH SUDAN
# 171        321                                           REUNION
# 172        127                                           ROMANIA
# 173        158                                            RUSSIA
# 174        376                                            RWANDA
# 175        128                                        SAN MARINO
# 176        330                             SAO TOME AND PRINCIPE
# 177        261                                      SAUDI ARABIA
# 178        391                                           SENEGAL
# 179        142                             SERBIA AND MONTENEGRO
# 180        745                                            SERBIA
# 181        347                                        SEYCHELLES
# 182        348                                      SIERRA LEONE
# 183        207                                         SINGAPORE
# 184        141                                          SLOVAKIA
# 185        166                                          SLOVENIA
# 186        412                                   SOLOMON ISLANDS
# 187        397                                           SOMALIA
# 188        373                                      SOUTH AFRICA
# 189        276                                       SOUTH KOREA
# 190        129                                             SPAIN
# 191        244                                         SRI LANKA
# 192        346                                        ST. HELENA
# 193        522                                   ST. KITTS-NEVIS
# 194        523                                         ST. LUCIA
# 195        502                           ST. PIERRE AND MIQUELON
# 196        524                            ST. VINCENT-GRENADINES
# 197        716                                  SAINT BARTHELEMY
# 198        736                                      SAINT MARTIN
# 199        749                                     SAINT MAARTEN
# 200        350                                             SUDAN
# 201        602                                          SURINAME
# 202        351                                         SWAZILAND
# 203        130                                            SWEDEN
# 204        131                                       SWITZERLAND
# 205        262                                             SYRIA
# 206        268                                            TAIWAN
# 207        159                                        TAJIKISTAN
# 208        353                                          TANZANIA
# 209        263                                          THAILAND
# 210        304                                              TOGO
# 211        417                                             TONGA
# 212        516                               TRINIDAD AND TOBAGO
# 213        323                                           TUNISIA
# 214        264                                            TURKEY
# 215        161                                      TURKMENISTAN
# 216        527                          TURKS AND CAICOS ISLANDS
# 217        420                                            TUVALU
# 218        352                                            UGANDA
# 219        162                                           UKRAINE
# 220        296                              UNITED ARAB EMIRATES
# 221        135                                    UNITED KINGDOM
# 222        695                                           URUGUAY
# 223        163                                        UZBEKISTAN
# 224        410                                           VANUATU
# 225        696                                         VENEZUELA
# 226        266                                           VIETNAM
# 227        469                         WALLIS AND FUTUNA ISLANDS
# 228        757                              WEST INDIES (FRENCH)
# 229        333                                    WESTERN SAHARA
# 230        465                                     WESTERN SAMOA
# 231        216                                             YEMEN
# 232        139                                        YUGOSLAVIA
# 233        301                                             ZAIRE
# 234        344                                            ZAMBIA
# 235        315                                          ZIMBABWE
# 236        403                           INVALID: AMERICAN SAMOA
# 237        712                               INVALID: ANTARCTICA
# 238        700                       INVALID: BORN ON BOARD SHIP
# 239        719  INVALID: BOUVET ISLAND (ANTARCTICA/NORWAY TERR.)
# 240        574                                   INVALID: CANADA
# 241        720                INVALID: CANTON AND ENDERBURY ISLS
# 242        106                           INVALID: CZECHOSLOVAKIA
# 243        739   INVALID: DRONNING MAUD LAND (ANTARCTICA-NORWAY)
# 244        394            INVALID: FRENCH SOUTHERN AND ANTARCTIC
# 245        501                                INVALID: GREENLAND
# 246        404                                     INVALID: GUAM
# 247        730                     INVALID: INTERNATIONAL WATERS
# 248        731                           INVALID: JOHNSON ISLAND
# 249        471                INVALID: MARIANA ISLANDS, NORTHERN
# 250        737                           INVALID: MIDWAY ISLANDS
# 251        753             INVALID: MINOR OUTLYING ISLANDS - USA
# 252        740            INVALID: NEUTRAL ZONE (S. ARABIA/IRAQ)
# 253        710                      INVALID: NON-QUOTA IMMIGRANT
# 254        505                              INVALID: PUERTO RICO
# 255          0                                INVALID: STATELESS
# 256        705                                INVALID: STATELESS
# 257        583                            INVALID: UNITED STATES
# 258        407                            INVALID: UNITED STATES
# 259        999                                  INVALID: UNKNOWN
# 260        239                          INVALID: UNKNOWN COUNTRY
# 261        134                                     INVALID: USSR
# 262        506                      INVALID: U.S. VIRGIN ISLANDS
# 263        755                              INVALID: WAKE ISLAND
# 264        311              Collapsed Tanzania (should not show)
# 265        741               Collapsed Curacao (should not show)
# 266         54                              No Country Code (54)
# 267        100                             No Country Code (100)
# 268        187                             No Country Code (187)
# 269        190                             No Country Code (190)
# 270        200                             No Country Code (200)
# 271        219                             No Country Code (219)
# 272        238                             No Country Code (238)
# 273        277                             No Country Code (277)
# 274        293                             No Country Code (293)
# 275        300                             No Country Code (300)
# 276        319                             No Country Code (319)
# 277        365                             No Country Code (365)
# 278        395                             No Country Code (395)
# 279        400                             No Country Code (400)
# 280        485                             No Country Code (485)
# 281        503                             No Country Code (503)
# 282        589                             No Country Code (589)
# 283        592                             No Country Code (592)
# 284        791                             No Country Code (791)
# 285        849                             No Country Code (849)
# 286        914                             No Country Code (914)
# 287        944                             No Country Code (944)
# 288        996                             No Country Code (996)
