# %%
import findspark
findspark.init()

import pyspark.sql.functions as F
import pyspark.sql.types as T

import pandas as pd
pd.set_option('display.max_rows', 1000)

from etl import SparkETL

# %%
etl = SparkETL()

# %%
spark = etl.get_spark()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/Cellar/apache-spark/3.1.2/libexec/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/05/05 15:44:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
table_schema = T.ArrayType(T.ArrayType(T.StringType(),True),True)

i94_data_dict_schema = T.StructType([
    T.StructField('I94ADDR', table_schema, True),
    T.StructField('I94CIT', table_schema, True),
    T.StructField('I94MODE', table_schema, True),
    T.StructField('I94PORT', table_schema, True),
    T.StructField('VISATYPE', table_schema, True)
])

# %%
i94_data_dict_staging = (
    spark.read
    .format('json')
    .schema(i94_data_dict_schema)
    .option('multiline', 'true')
    .load(etl.data_sources['ports'])
)

# %%
def port_dictionary(df):
    return df.select('I94PORT')

# %%
def explode_dictionary(df):
    return (
        df
        .select(F.explode(port_col))
        .select(
            F.trim(F.element_at(F.col('col'), 1)).alias('port_id'),
            F.trim(F.element_at(F.col('col'), 2)).alias('port_desc')
        )
    )

# %%
state_suffix_expr = F.col('port_desc').rlike(', ?[A-Z]{2}$')

# %%
def filter_with_state_suffix(df):
    return df.where(state_suffix_expr)

# %%
def filter_without_state_suffix(df):
    return df.where(~state_suffix_expr)

# %%
def drop_mx_ports(df):
    """
    Mexican immigration ports are out of scope.
    """
    return df.where(~F.col('port_desc').rlike('MX$'))

# %%
def drop_unrecoverable_ports(df):
    """
    - we can't expect to extract information from them, like state and city
    - we can't expect to use them to join to other tables
    """
    return df.where(
        ~(
            F.col('port_desc').like('%No PORT Code%')
            | F.col('port_desc').like('%UNKNOWN%')
            | F.col('port_desc').like('%UNIDENTIFED%')
        )
    )

# %%
def drop_individual_ports(df):
    return df.where(
        ~(
            F.col('port_id').like('INT') 
            | F.col('port_id').like('ZZZ')
        )
    )

# %%
def clean_bps_ports(df):
        
    expr = F.expr(
    """
    IF(
        RLIKE(port_desc, ", [A-Z]{2} ((\(.*\))|(#ARPT))$"),
        REGEXP_EXTRACT(port_desc, "(.*, [A-Z]{2}) ((\(.*\))|(#ARPT))$", 1),
        port_desc
    )
    """
    )
    
    return df.withColumn('port_desc', expr)

# %%
def manually_replace(search, replace):
    return F.expr(f"replace(port_desc, '{search}', '{replace}')")

# %%
def manually_clean_ports(df):
    return (
        df
        .withColumn('port_desc', manually_replace('MARIPOSA AZ', 'MARIPOSA, AZ'))
        .withColumn('port_desc', manually_replace('WASHINGTON DC', 'WASHINGTON, DC'))
        .withColumn('port_desc', manually_replace('BELLINGHAM, WASHINGTON #INTL', 'BELLINGHAM, WA'))
    )

# %%
def split_port_desc(df):
    return (
        df
        .withColumn(
            'state_id',
            F.trim(
                F.substring_index(F.col('port_desc'), ',', -1)
            )
        )
        .withColumn(
            'name',
            F.trim(
                F.regexp_extract(F.col('port_desc'), '^(.*), ?[A-Z]{2}$', 1)
            )
        )
    )

# %%
def clean_collapsed_into_ports(df):
    return (
        df
        .withColumn('port_desc', F.expr("""
        IF(
            port_desc LIKE 'Collapsed into%',
            'INT, MN',
            port_desc
        )
        """))
    )

# %%
def drop_port_desc(df):
    return df.drop('port_desc')

# %%
def non_collapsed_ports(df):
    return (
        df
        .pipe(port_dictionary)
        .pipe(explode_dictionary)
        .pipe(drop_unrecoverable_ports)
        .pipe(drop_individual_ports)
        .pipe(clean_bps_ports)
        .pipe(manually_clean_ports) 
        .pipe(drop_mx_ports)
        .pipe(clean_collapsed_into_ports)
        .pipe(filter_with_state_suffix)
        .pipe(split_port_desc)
        .pipe(drop_port_desc)
    )

# %%
def prepare_collapsed_ports(df):
    return (
        df
        .pipe(port_dictionary)
        .pipe(explode_dictionary)
        .where(F.col('port_desc').like('Collapsed (%'))
        .select(
            F.col('port_id').alias('from_port_id'),
            F.regexp_extract(
                'port_desc',
                '^Collapsed \((.*)\)',
                1
            )
            .alias('to_port_id')
        )
    )

# %%
def merge_collapsed_ports(df):
    
    collapsed = port_staging.pipe(prepare_collapsed_ports)
    
    return (
        df
        .join(
            collapsed,
            on=collapsed['to_port_id'] == df['port_id'],
            how='inner'
        )
    )

# %%
def drop_after_merge(df):
    return (
        df
        .select(
            F.expr("""
                IF(
                    ISNOTNULL(from_port_id),
                    from_port_id,
                    port_id
                )
            """)
            .alias('port_id'),
            'state_id',
            'name'
        )
    )

# %%
def collapsed_ports(df):
    return (
        df
        .pipe(non_collapsed_ports)
        .pipe(merge_collapsed_ports)
        .pipe(drop_after_merge)
    )

# %%
def ports_union(df):
    return (
        df.
        pipe(non_collapsed_ports)
        .union(
            df.pipe(collapsed_ports)
        )
    )

# %%
def remove_ports_with_non_standard_states(df):
    
    states = etl.read_clean_table('state')
    
    state_ids = states.select(F.col('state_id').alias('id'))

    return (
        df
        .join(
            state_ids,
            on=df['state_id'] == state_ids['id'],
            how='inner'
        )
        .drop('id')
    )

# %%
def clean_ports(df):
    return (
        df
        .pipe(ports_union)
        .pipe(remove_ports_with_non_standard_states)
    )

# %%
def save_clean_ports(df):
    etl.save_clean_table(
        df.pipe(clean_ports).coalesce(1),
        'port'
    )

# %%
save_clean_ports(port_staging)

# %%
etl.read_clean_table('port').toPandas()
# Out:
#     port_id state_id                           name
# 0       ALC       AK                          ALCAN
# 1       ANC       AK                      ANCHORAGE
# 2       BAR       AK       BAKER AAF - BAKER ISLAND
# 3       DAC       AK                  DALTONS CACHE
# 4       PIZ       AK         DEW STATION PT LAY DEW
# 5       DTH       AK                   DUTCH HARBOR
# 6       EGL       AK                          EAGLE
# 7       FRB       AK                      FAIRBANKS
# 8       HOM       AK                          HOMER
# 9       HYD       AK                          HYDER
# 10      JUN       AK                         JUNEAU
# 11      5KE       AK                      KETCHIKAN
# 12      KET       AK                      KETCHIKAN
# 13      MOS       AK       MOSES POINT INTERMEDIATE
# 14      NIK       AK                        NIKISKI
# 15      NOM       AK                            NOM
# 16      PKC       AK                    POKER CREEK
# 17      ORI       AK                 PORT LIONS SPB
# 18      SKA       AK                        SKAGWAY
# 19      SNP       AK                ST. PAUL ISLAND
# 20      TKI       AK                         TOKEEN
# 21      WRA       AK                       WRANGELL
# 22      HSV       AL    MADISON COUNTY - HUNTSVILLE
# 23      MOB       AL                         MOBILE
# 24      LIA       AR                    LITTLE ROCK
# 25      ROG       AR                    ROGERS ARPT
# 26      DOU       AZ                        DOUGLAS
# 27      LUK       AZ                      LUKEVILLE
# 28      MAP       AZ                       MARIPOSA
# 29      NAC       AZ                           NACO
# 30      NOG       AZ                        NOGALES
# 31      PHO       AZ                        PHOENIX
# 32      POR       AZ                         PORTAL
# 33      SLU       AZ                       SAN LUIS
# 34      SAS       AZ                         SASABE
# 35      TUC       AZ                         TUCSON
# 36      YUI       AZ                           YUMA
# 37      AND       CA                        ANDRADE
# 38      BUR       CA                        BURBANK
# 39      CAL       CA                       CALEXICO
# 40      CAO       CA                          CAMPO
# 41      FRE       CA                         FRESNO
# 42      ICP       CA                IMPERIAL COUNTY
# 43      LNB       CA                     LONG BEACH
# 44      LOS       CA                    LOS ANGELES
# 45      BFL       CA    MEADOWS FIELD - BAKERSFIELD
# 46      OAK       CA                        OAKLAND
# 47      ONT       CA                        ONTARIO
# 48      OTM       CA                      OTAY MESA
# 49      BLT       CA          PACIFIC, HWY. STATION
# 50      PSP       CA                   PALM SPRINGS
# 51      SAC       CA                     SACRAMENTO
# 52      SLS       CA                        SALINAS
# 53      SDP       CA                      SAN DIEGO
# 54      SFR       CA                  SAN FRANCISCO
# 55      SNJ       CA                       SAN JOSE
# 56      SLO       CA                SAN LUIS OBISPO
# 57      SLI       CA                SAN LUIS OBISPO
# 58      SPC       CA                      SAN PEDRO
# 59      SYS       CA                     SAN YSIDRO
# 60      SAA       CA                      SANTA ANA
# 61      STO       CA                       STOCKTON
# 62      TEC       CA                         TECATE
# 63      TRV       CA                     TRAVIS-AFB
# 64      APA       CO                ARAPAHOE COUNTY
# 65      ASE       CO                          ASPEN
# 66      COS       CO               COLORADO SPRINGS
# 67      DEN       CO                         DENVER
# 68      DRO       CO             LA PLATA - DURANGO
# 69      BDL       CT          BRADLEY INTERNATIONAL
# 70      BGC       CT                     BRIDGEPORT
# 71      GRT       CT                         GROTON
# 72      HAR       CT                       HARTFORD
# 73      NWH       CT                      NEW HAVEN
# 74      NWL       CT                     NEW LONDON
# 75      TST       CT     NEWINGTON DATA CENTER TEST
# 76      WAS       DC                     WASHINGTON
# 77      DOV       DE                      DOVER AFB
# 78      DVD       DE                      DOVER-AFB
# 79      WLL       DE                     WILMINGTON
# 80      BOC       FL                     BOCAGRANDE
# 81      SRQ       FL           BRADENTON - SARASOTA
# 82      CAN       FL                 CAPE CANAVERAL
# 83      DAB       FL    DAYTONA BEACH INTERNATIONAL
# 84      FRN       FL                     FERNANDINA
# 85      FTL       FL                FORT LAUDERDALE
# 86      FMY       FL                     FORT MYERS
# 87      FPF       FL                    FORT PIERCE
# 88      HUR       FL                 HURLBURT FIELD
# 89      GNV       FL  J R ALISON MUNI - GAINESVILLE
# 90      JAC       FL                   JACKSONVILLE
# 91      KEY       FL                       KEY WEST
# 92      LEE       FL     LEESBURG MUNICIPAL AIRPORT
# 93      MLB       FL                      MELBOURNE
# 94      MIA       FL                          MIAMI
# 95      APF       FL                         NAPLES
# 96      OPF       FL                      OPA LOCKA
# 97      ORL       FL                        ORLANDO
# 98      PAN       FL                    PANAMA CITY
# 99      PEN       FL                      PENSACOLA
# 100     PCF       FL                 PORT CANAVERAL
# 101     PEV       FL                PORT EVERGLADES
# 102     PSJ       FL                    PORT ST JOE
# 103     SFB       FL                        SANFORD
# 104     SGJ       FL              ST AUGUSTINE ARPT
# 105     SAU       FL                   ST AUGUSTINE
# 106     FPR       FL                ST LUCIE COUNTY
# 107     SPE       FL                  ST PETERSBURG
# 108     TAM       FL                          TAMPA
# 109     WPB       FL                WEST PALM BEACH
# 110     ATL       GA                        ATLANTA
# 111     BRU       GA                      BRUNSWICK
# 112     AGS       GA           BUSH FIELD - AUGUSTA
# 113     SAV       GA                       SAVANNAH
# 114     AGA       GU                          AGANA
# 115     HHW       HI                       HONOLULU
# 116     OGG       HI                 KAHULUI - MAUI
# 117     KOA       HI                   KEAHOLE-KONA
# 118     LIH       HI                          LIHUE
# 119     CID       IA         CEDAR RAPIDS/IOWA CITY
# 120     DSM       IA                     DES MOINES
# 121     BOI       ID    AIR TERM. (GOWEN FLD) BOISE
# 122     EPI       ID                       EASTPORT
# 123     IDA       ID    FANNING FIELD - IDAHO FALLS
# 124     PTL       ID                       PORTHILL
# 125     SPI       IL          CAPITAL - SPRINGFIELD
# 126     CHI       IL                        CHICAGO
# 127     DPA       IL                  DUPAGE COUNTY
# 128     PIA       IL                 GREATER PEORIA
# 129     RFD       IL               GREATER ROCKFORD
# 130     UGN       IL            MEMORIAL - WAUKEGAN
# 131     GAR       IN                           GARY
# 132     HMM       IN                        HAMMOND
# 133     INP       IN                   INDIANAPOLIS
# 134     MRL       IN                   MERRILLVILLE
# 135     SBN       IN                     SOUTH BEND
# 136     ICT       KS       MID-CONTINENT - WITCHITA
# 137     LEX       KY         BLUE GRASS - LEXINGTON
# 138     LOU       KY                     LOUISVILLE
# 139     BTN       LA                    BATON ROUGE
# 140     LKC       LA                   LAKE CHARLES
# 141     LAK       LA                   LAKE CHARLES
# 142     MLU       LA                         MONROE
# 143     MGC       LA                    MORGAN CITY
# 144     NOL       LA                    NEW ORLEANS
# 145     BOS       MA                         BOSTON
# 146     GLO       MA                     GLOUCESTER
# 147     BED       MA        HANSCOM FIELD - BEDFORD
# 148     LYN       WA                         LYNDEN
# 149     ADW       MD                    ANDREWS AFB
# 150     BAL       MD                      BALTIMORE
# 151     MKG       MD                       MUSKEGON
# 152     PAX       MD                 PATUXENT RIVER
# 153     BGM       ME                         BANGOR
# 154     BOO       ME                BOOTHBAY HARBOR
# 155     BWM       ME                    BRIDGEWATER
# 156     BCK       ME                       BUCKPORT
# 157     CLS       ME                         CALAIS
# 158     CRB       ME                        CARIBOU
# 159     COB       ME                    COBURN GORE
# 160     EST       ME                      EASTCOURT
# 161     EPT       ME             EASTPORT MUNICIPAL
# 162     EPM       ME                       EASTPORT
# 163     FOR       ME                    FOREST CITY
# 164     FTF       ME                 FORT FAIRFIELD
# 165     FTK       ME                      FORT KENT
# 166     HML       ME                         HAMIIN
# 167     HTM       ME                        HOULTON
# 168     JKM       ME                        JACKMAN
# 169     KAL       MT                       KALISPEL
# 170     LIM       ME                      LIMESTONE
# 171     LUB       ME                          LUBEC
# 172     MAD       ME                      MADAWASKA
# 173     POM       ME                       PORTLAND
# 174     RGM       ME                       RANGELEY
# 175     SBR       ME                   SOUTH BREWER
# 176     SRL       ME                     ST AURELIE
# 177     SPA       ME                     ST PAMPILE
# 178     VNB       ME                      VAN BUREN
# 179     VCB       ME                      VANCEBORO
# 180     AGN       MI                        ALGONAC
# 181     ALP       MI                         ALPENA
# 182     BCY       MI                       BAY CITY
# 183     DET       MI                        DETROIT
# 184     GRP       MI                   GRAND RAPIDS
# 185     GRO       MI                    GROSSE ISLE
# 186     ISL       MI                    ISLE ROYALE
# 187     MRC       MI                    MARINE CITY
# 188     MRY       MI                     MARYSVILLE
# 189     PTK       MI       OAKLAND COUNTY - PONTIAC
# 190     PHU       MI                     PORT HURON
# 191     RBT       MI                ROBERTS LANDING
# 192     SAG       MI                        SAGINAW
# 193     SSM       MI               SAULT STE. MARIE
# 194     SCL       MI                       ST CLAIR
# 195     YIP       MI         WILLOW RUN - YPSILANTI
# 196     BAU       MN                       BAUDETTE
# 197     CAR       MN      CARIBOU MUNICIPAL AIRPORT
# 198     GTF       MN                            INT
# 199     INL       MN                            INT
# 200     CRA       MN                     CRANE LAKE
# 201     MIC       MN      CRYSTAL MUNICIPAL AIRPORT
# 202     DUL       MN                         DULUTH
# 203     ELY       MN                            ELY
# 204     GPM       MN                  GRAND PORTAGE
# 205     SVC       MN     GRANT COUNTY - SILVER CITY
# 206     LAN       MN                      LANCASTER
# 207     MSP       MN                  MINN./ST PAUL
# 208     LIN       MN            NORTHERN SVC CENTER
# 209     NOY       MN                          NOYES
# 210     PIN       MN                     PINE CREEK
# 211     48Y       MN          PINECREEK BORDER ARPT
# 212     RAN       MN                         RAINER
# 213     RST       MN                      ROCHESTER
# 214     ROS       MN                         ROSEAU
# 215     SPM       MN                        ST PAUL
# 216     WSB       MN              WARROAD INTL, SPB
# 217     WAR       MN                        WARROAD
# 218     KAN       MO                    KANSAS CITY
# 219     SGF       MO            SPRINGFIELD-BRANSON
# 220     STL       MO                       ST LOUIS
# 221     WHI       MT                      WHITETAIL
# 222     WHM       MT                     WILD HORSE
# 223     GPT       MS                BILOXI REGIONAL
# 224     GTR       MS   GOLDEN TRIANGLE LOWNDES CNTY
# 225     GUL       MS                       GULFPORT
# 226     PAS       MS                     PASCAGOULA
# 227     JAN       MS       THOMPSON FIELD - JACKSON
# 228     BIL       MT                       BILLINGS
# 229     BTM       MT                          BUTTE
# 230     CHF       MT                       CHIEF MT
# 231     CTB       MT             CUT BANK MUNICIPAL
# 232     CUT       MT                       CUT BANK
# 233     DLB       MT                     DEL BONITA
# 234     EUR       MT                         EUREKA
# 235     BZN       MT       GALLATIN FIELD - BOZEMAN
# 236     FCA       MT          GLACIER NATIONAL PARK
# 237     GGW       MT                        GLASGOW
# 238     GRE       MT                    GREAT FALLS
# 239     HVR       MT                          HAVRE
# 240     HEL       MT                         HELENA
# 241     LWT       MT                       LEWISTON
# 242     MGM       MT                         MORGAN
# 243     OPH       MT                         OPHEIM
# 244     PIE       MT                         PIEGAN
# 245     RAY       MT                        RAYMOND
# 246     ROO       MT                      ROOSVILLE
# 247     SCO       MT                         SCOBEY
# 248     SWE       MT                     SWEETGTASS
# 249     TRL       MT                    TRIAL CREEK
# 250     TUR       MT                         TURNER
# 251     WCM       MT                   WILLOW CREEK
# 252     CLT       NC                      CHARLOTTE
# 253     FAY       NC                   FAYETTEVILLE
# 254     MRH       NC                  MOREHEAD CITY
# 255     FOP       NC              MORRIS FIELDS AAF
# 256     GSO       NC    PIEDMONT TRIAD INTL AIRPORT
# 257     RDU       NC                 RALEIGH/DURHAM
# 258     SSC       NC              SHAW AFB - SUMTER
# 259     WIL       NC                     WILMINGTON
# 260     AMB       ND                        AMBROSE
# 261     ANT       ND                         ANTLER
# 262     CRY       ND                        CARBURY
# 263     DNS       ND                       DUNSEITH
# 264     FAR       ND                          FARGO
# 265     FRT       ND                        FORTUNA
# 266     GRF       ND                    GRAND FORKS
# 267     HNN       ND                         HANNAH
# 268     HNS       ND                       HANSBORO
# 269     MAI       ND                          MAIDA
# 270     MND       ND                          MINOT
# 271     NEC       ND                          NECHE
# 272     NOO       ND                         NOONAN
# 273     NRG       ND                      NORTHGATE
# 274     PEM       ND                        PEMBINA
# 275     SAR       ND                         SARLES
# 276     SHR       ND                       SHERWOOD
# 277     SJO       ND                        ST JOHN
# 278     WAL       ND                       WALHALLA
# 279     WHO       ND                       WESTHOPE
# 280     WND       ND                      WILLISTON
# 281     OMA       NE                          OMAHA
# 282     LEB       NH                        LEBANON
# 283     MHT       NH                     MANCHESTER
# 284     PNH       NH                      PITTSBURG
# 285     PSM       NH                     PORTSMOUTH
# 286     BYO       NJ                        BAYONNE
# 287     CNJ       NJ                         CAMDEN
# 288     HOB       NJ                        HOBOKEN
# 289     JER       NJ                    JERSEY CITY
# 290     WRI       NJ      MC GUIRE AFB - WRIGHTSOWN
# 291     MMU       NJ                     MORRISTOWN
# 292     NEW       NJ               NEWARK/TETERBORO
# 293     PER       NJ                    PERTH AMBOY
# 294     ACY       NJ   POMONA FIELD - ATLANTIC CITY
# 295     ALA       NM                     ALAMAGORDO
# 296     ABQ       NM                    ALBUQUERQUE
# 297     ANP       NM                 ANTELOPE WELLS
# 298     CRL       NM                       CARLSBAD
# 299     COL       NM                       COLUMBUS
# 300     CDD       NM    CRANE LAKE - ST. LOUIS CNTY
# 301     DNM       NM                         DEMING
# 302     LAS       NM                     LAS CRUCES
# 303     LOB       NM                      LORDSBURG
# 304     RUI       NM                        RUIDOSO
# 305     STR       NM                   SANTA TERESA
# 306     RNO       NV       CANNON INTL - RENO/TAHOE
# 307     FLX       NV       FALLON MUNICIPAL AIRPORT
# 308     LVG       NV                      LAS VEGAS
# 309     REN       NV                           RENO
# 310     ALB       NY                         ALBANY
# 311     AXB       NY                 ALEXANDRIA BAY
# 312     BUF       NY                        BUFFALO
# 313     CNH       NY                 CANNON CORNERS
# 314     CAP       NY                   CAPE VINCENT
# 315     CHM       NY                      CHAMPLAIN
# 316     CHT       NY                     CHATEAUGAY
# 317     CLA       NY                        CLAYTON
# 318     FTC       NY                 FORT COVINGTON
# 319     LAG       NY                     LA GUARDIA
# 320     LEW       NY                       LEWISTON
# 321     MAS       NY                        MASSENA
# 322     MAG       NY                    MCGUIRE AFB
# 323     MOO       NY                         MOORES
# 324     MRR       NY                     MORRISTOWN
# 325     NYC       NY                       NEW YORK
# 326     NIA       NY                  NIAGARA FALLS
# 327     OGD       NY                     OGDENSBURG
# 328     OSW       NY                         OSWEGO
# 329     ELM       NY      REGIONAL ARPT - HORSEHEAD
# 330     ROC       NY                      ROCHESTER
# 331     ROU       NY                   ROUSES POINT
# 332     SWF       NY          STEWART - ORANGE CNTY
# 333     SYR       NY                       SYRACUSE
# 334     THO       NY         THOUSAND ISLAND BRIDGE
# 335     TRO       NY                    TROUT RIVER
# 336     WAT       NY                      WATERTOWN
# 337     HPN       NY     WESTCHESTER - WHITE PLAINS
# 338     WRB       NY               WHIRLPOOL BRIDGE
# 339     YOU       NY                     YOUNGSTOWN
# 340     AKR       OH                          AKRON
# 341     ATB       OH                      ASHTABULA
# 342     CIN       OH                     CINCINNATI
# 343     CLE       OH                      CLEVELAND
# 344     CLM       OH                       COLUMBUS
# 345     LOR       OH                         LORAIN
# 346     MBO       OH                   MARBLE HEADS
# 347     SDY       OH                       SANDUSKY
# 348     TOL       OH                         TOLEDO
# 349     OKC       OK                  OKLAHOMA CITY
# 350     TUL       OK                          TULSA
# 351     AST       OR                        ASTORIA
# 352     COO       OR                       COOS BAY
# 353     HIO       OR                      HILLSBORO
# 354     MED       OR                        MEDFORD
# 355     NPT       OR                        NEWPORT
# 356     POO       OR                       PORTLAND
# 357     PUT       OH                     PUT-IN-BAY
# 358     RDM       OR       ROBERTS FIELDS - REDMOND
# 359     ERI       PA                           ERIE
# 360     MDT       PA                     HARRISBURG
# 361     HSB       PA                   HARRISONBURG
# 362     PHI       PA                   PHILADELPHIA
# 363     PIT       PA                      PITTSBURG
# 364     AGU       PR                      AGUADILLA
# 365     BQN       PR          BORINQUEN - AGUADILLO
# 366     JCP       PR      CULEBRA - BENJAMIN RIVERA
# 367     ENS       PR                       ENSENADA
# 368     FAJ       PR                        FAJARDO
# 369     HUM       PR                        HUMACAO
# 370     JOB       PR                          JOBOS
# 371     MAY       PR                       MAYAGUEZ
# 372     PON       PR                          PONCE
# 373     PSE       PR                PONCE-MERCEDITA
# 374     SAJ       PR                       SAN JUAN
# 375     VQS       PR                   VIEQUES-ARPT
# 376     PRO       RI                     PROVIDENCE
# 377     PVD       RI     THEODORE FRANCIS - WARWICK
# 378     CHL       SC                     CHARLESTON
# 379     CAE       SC                       COLUMBIA
# 380     GEO       SC                     GEORGETOWN
# 381     GSP       SC                     GREENVILLE
# 382     GRR       SC                          GREER
# 383     MYR       SC                   MYRTLE BEACH
# 384     SPF       SD         BLACK HILLS, SPEARFISH
# 385     HON       SD    HOWES REGIONAL ARPT - HURON
# 386     TYS       TN          MC GHEE TYSON - ALCOA
# 387     MEM       TN                        MEMPHIS
# 388     NSV       TN                      NASHVILLE
# 389     TRI       TN                  TRI CITY ARPT
# 390     ADS       TX       ADDISON AIRPORT- ADDISON
# 391     ADT       TX                    AMISTAD DAM
# 392     ANZ       TX                      ANZALDUAS
# 393     AUS       TX                         AUSTIN
# 394     BEA       TX                       BEAUMONT
# 395     BBP       TX                  BIG BEND PARK
# 396     SCC       TX             BP SPEC COORD. CTR
# 397     BTC       TX               BP TACTICAL UNIT
# 398     BOA       TX             BRIDGE OF AMERICAS
# 399     BRO       TX                    BROWNSVILLE
# 400     CRP       TX                 CORPUS CHRISTI
# 401     DAL       TX                         DALLAS
# 402     DLR       TX                        DEL RIO
# 403     DNA       TX                          DONNA
# 404     EGP       TX                     EAGLE PASS
# 405     ELP       TX                        EL PASO
# 406     FAB       TX                         FABENS
# 407     FAL       TX                 FALCON HEIGHTS
# 408     FTH       TX                   FORT HANCOCK
# 409     AFW       TX            FORT WORTH ALLIANCE
# 410     FPT       TX                       FREEPORT
# 411     GAL       TX                      GALVESTON
# 412     HLG       TX                      HARLINGEN
# 413     HID       TX                        HIDALGO
# 414     HOU       TX                        HOUSTON
# 415     SGR       TX    HULL FIELD, SUGAR LAND ARPT
# 416     LLB       TX          JUAREZ-LINCOLN BRIDGE
# 417     LCB       TX         LAREDO COLUMBIA BRIDGE
# 418     LRN       TX                   LAREDO NORTH
# 419     LAR       TX                         LAREDO
# 420     LSE       TX                     LOS EBANOS
# 421     IND       TX                     LOS INDIOS
# 422     LOI       TX                     LOS INDIOS
# 423     MRS       TX                          MARFA
# 424     MCA       TX                        MCALLEN
# 425     MAF       TX                ODESSA REGIONAL
# 426     PDN       TX                 PASO DEL NORTE
# 427     PBB       NY                   PEACE BRIDGE
# 428     PHR       TX                          PHARR
# 429     PAR       TX                    PORT ARTHUR
# 430     ISB       TX                    PORT ISABEL
# 431     POE       TX                PORT OF EL PASO
# 432     PRE       TX                       PRESIDIO
# 433     PGR       TX                       PROGRESO
# 434     RIO       TX                RIO GRANDE CITY
# 435     ROM       TX                           ROMA
# 436     SNA       TX                    SAN ANTONIO
# 437     SNN       TX                      SANDERSON
# 438     VIB       TX            VETERAN INTL BRIDGE
# 439     YSL       TX                         YSLETA
# 440     CHA       VI               CHARLOTTE AMALIE
# 441     CHR       VI                  CHRISTIANSTED
# 442     FRK       VI                   FREDERIKSTED
# 443     STT       VI                      ST THOMAS
# 444     LGU       UT          CACHE AIRPORT - LOGAN
# 445     SLC       UT                 SALT LAKE CITY
# 446     CHO       VA      ALBEMARLE CHARLOTTESVILLE
# 447     DAA       VA     DAVISON AAF - FAIRFAX CNTY
# 448     HOP       VA                       HOPEWELL
# 449     HEF       VA                       MANASSAS
# 450     NWN       VA                        NEWPORT
# 451     NOR       VA                        NORFOLK
# 452     RCM       VA                       RICHMOND
# 453     ABS       VT                 ALBURG SPRINGS
# 454     ABG       VT                         ALBURG
# 455     BEB       VT                    BEEBE PLAIN
# 456     BEE       VT                  BEECHER FALLS
# 457     BRG       VT                     BURLINGTON
# 458     CNA       VT                         CANAAN
# 459     DER       VT                     DERBY LINE
# 460     DLV       VT                     DERBY LINE
# 461     ERC       VT                  EAST RICHFORD
# 462     HIG       VT               HIGHGATE SPRINGS
# 463     MOR       VT                    MORSES LINE
# 464     NPV       VT                        NEWPORT
# 465     NRT       VT                     NORTH TROY
# 466     NRN       VT                         NORTON
# 467     PIV       VT                  PINNACLE ROAD
# 468     RIF       VT                       RICHFORT
# 469     STA       VT                      ST ALBANS
# 470     SWB       VT                        SWANTON
# 471     WBE       VT                 WEST BERKSHIRE
# 472     ABE       WA                       ABERDEEN
# 473     ANA       WA                      ANACORTES
# 474     BEL       WA                     BELLINGHAM
# 475     BLI       WA                     BELLINGHAM
# 476     BLA       WA                         BLAINE
# 477     BWA       WA                       BOUNDARY
# 478     CUR       WA                         CURLEW
# 479     DVL       WA                       DANVILLE
# 480     EVE       WA                        EVERETT
# 481     FER       WA                          FERRY
# 482     FRI       WA                  FRIDAY HARBOR
# 483     FWA       WA                       FRONTIER
# 484     KLM       WA                         KALAMA
# 485     LAU       WA                        LAURIER
# 486     LON       WA                       LONGVIEW
# 487     MET       WA                 METALINE FALLS
# 488     MWH       WA   MOSES LAKE GRANT COUNTY ARPT
# 489     NEA       WA                       NEAH BAY
# 490     NIG       WA                      NIGHTHAWK
# 491     OLY       WA                        OLYMPIA
# 492     ORO       WA                       OROVILLE
# 493     PWB       WA                          PASCO
# 494     PIR       WA                  POINT ROBERTS
# 495     PNG       WA                   PORT ANGELES
# 496     PTO       WA                  PORT TOWNSEND
# 497     SEA       WA                        SEATTLE
# 498     SPO       WA                        SPOKANE
# 499     SUM       WA                          SUMAS
# 500     TAC       WA                         TACOMA
# 501     PSC       WA             TRI-CITIES - PASCO
# 502     VAN       WA                      VANCOUVER
# 503     AGM       WI                         ALGOMA
# 504     BAY       WI                       BAYFIELD
# 505     GRB       WI                      GREEN BAY
# 506     MNW       WI                      MANITOWOC
# 507     MIL       WI                      MILWAUKEE
# 508     MSN       WI      TRUAX FIELD - DANE COUNTY
# 509     CHS       WV                     CHARLESTON
# 510     CLK       WV                     CLARKSBURG
# 511     BLF       WV                  MERCER COUNTY
# 512     CSP       WY                         CASPER
# 513     CNC       NY                 CANNON CORNERS
# 514     AG0       AR                       MAGNOLIA
# 515     BHM       ME                     BAR HARBOR
# 516     BHX       AL                     BIRMINGHAM
# 517     CAK       OH                          AKRON
# 518     FOK       NY                 SUFFOLK COUNTY
# 519     LND       WY                         LANDER
# 520     MAR       TX                          MARFA
# 521     MLI       IL                         MOLINE
# 522     RIV       CA                      RIVERSIDE
# 523     RME       NY                           ROME
# 524     VNY       CA                       VAN NUYS
# 525     YUM       AZ                           YUMA
# 526     VMB       ME                      VAN BUREN
# 527     PHN       MI                     PORT HURON
# 528     STN       NM                   SANTA TERESA
# 529     BUS       NY                        BUFFALO
# 530     IAG       NY                  NIAGARA FALLS
# 531     JSJ       PR                       SAN JUAN
# 532     HRL       TX                      HARLINGEN
# 533     T01       WA                        SEATTLE
# 534     ISP       NY                 SUFFOLK COUNTY
# 535     FRG       NY                 SUFFOLK COUNTY
